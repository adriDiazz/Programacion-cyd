# %% [markdown]
# Adrian diaz manzanares 22016494

# %% [markdown]
# Tuve problemas con la conexion en clase

# %% [markdown]
# Progrma uno fibonacci
#
#
# Esta es la secuencia de fibonacci recursiva:

# %%
from IPython.display import Image

# %%
Image(filename='im.jpeg')

# %%
def fib(n):
    if n<=1:
        return n 
    else:
        return (fib(n-1)+fib(n-2))

# %%
fib(40)
# Out:
# 102334155
